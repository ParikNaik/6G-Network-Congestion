# %% [markdown]
# Fill the csv file in data folder with symthetic data for testing and training the model using sionna

# %%
import numpy as np
import pandas as pd
import os
import sionna as sn

# %% [markdown]
# We want a sufficient amount of data, so we arbitrarily choose 15,000

# %%
num_samples = 15000

# %% [markdown]
# Check for gpu availability and memory

# %%
# !nvidia-smi
# Out:
# Mon Jun 15 19:50:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.74                 Driver Version: 591.74         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2060      WDDM  |   00000000:01:00.0  On |                  N/A |
# | 27%   60C    P5             31W /  190W |    1626MiB /   6144MiB |     38%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2616    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A            3712    C+G   C:\Windows\System32\svchost.exe       N/A      |
# |    0   N/A  N/A            5376    C+G   ...0_x64__8j3eq9eme6ctt\IGCC.exe      N/A      |
# |    0   N/A  N/A            5868    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A            6584    C+G   ...4__8wekyb3d8bbwe\Video.UI.exe      N/A      |
# |    0   N/A  N/A            7468    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A            8104    C+G   ....0.4022.62\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            9252    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A            9332    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A            9384    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           10592    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           10644    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10808    C+G   ...h_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A           11464    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           11548    C+G   ...h_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A           14516    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           15672    C+G   ...aries\Win64\EpicWebHelper.exe      N/A      |
# |    0   N/A  N/A           15736    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           16360    C+G   ...\app-3.5.12\GitHubDesktop.exe      N/A      |
# |    0   N/A  N/A           18060    C+G   ...s\Win64\EpicGamesLauncher.exe      N/A      |
# |    0   N/A  N/A           21872    C+G   ...Chrome\Application\chrome.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# *NOTE: if error occurs or gpu isn't detected, run using cloud gpu on google colab platform (free)

# %%
NUM_BITS_PER_SYMBOL = 2 

constellation = sn.phy.mapping.Constellation("qam", NUM_BITS_PER_SYMBOL)

constellation.show();
# Out:
# W0615 19:51:23.273000 22084 Lib\site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels
