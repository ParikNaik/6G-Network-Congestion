# %% [markdown]
# Fill the csv file in data folder with symthetic data for testing and training the model using sionna

# %%
import numpy as np
import pandas as pd
import os
import sionna as sn

# %% [markdown]
# We want a sufficient amount of data, so we arbitrarily choose 15,000

# %%
num_samples = 15000

# %% [markdown]
# Check for gpu availability and memory

# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# *NOTE: if error occurs or gpu isn't detected, run using cloud gpu on google colab platform (free)

# %% [markdown]
# Sionna is an open-source library developed by NVIDIA for simulating and researching wireless communication systems, particularly next-generation networks such as 5G and 6G. Built on top of PyTorch, it provides tools for modeling transmitters, receivers, communication channels, signal processing algorithms, and machine learning-based communication systems.
